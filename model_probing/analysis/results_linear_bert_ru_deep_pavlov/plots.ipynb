# %%
import pandas as pd

df = pd.read_csv('data.csv')
df
# Out:
#     Unnamed: 0  model_layer  0_precision  0_recall  0_f1-score  0_support  \
# 0            0          0.0     0.500000  0.642857    0.562500      168.0
# 1            1          1.0     0.543689  0.666667    0.598930      168.0
# 2            2          2.0     0.580000  0.690476    0.630435      168.0
# 3            3          3.0     0.629032  0.696429    0.661017      168.0
# 4            4          4.0     0.652406  0.726190    0.687324      168.0
# 5            5          5.0     0.687500  0.720238    0.703488      168.0
# 6            6          6.0     0.735632  0.761905    0.748538      168.0
# 7            7          7.0     0.750000  0.750000    0.750000      168.0
# 8            8          8.0     0.757396  0.761905    0.759644      168.0
# 9            9          9.0     0.787879  0.773810    0.780781      168.0
# 10          10         10.0     0.795031  0.761905    0.778116      168.0
# 11          11         11.0     0.761905  0.761905    0.761905      168.0
# ...

# %%
from matplotlib import pyplot as plt

def plot_each_column_in_same_plot(df):
    # plot each column in same plot
    df.plot()
    plt.show()

# %%
def plot_list_of_columns_in_y_axis(df, columns, plot_title='Precision'):
    # plot each column in same plot

    df.plot(y=columns)
    plt.title(plot_title)
    plt.legend(['Acc', 'Dat', 'Gen', 'Loc', 'Ins', 'Nom'], loc='lower right')
    plt.show()

# %%
plot_list_of_columns_in_y_axis(df,
                               columns=['0_precision', '1_precision', '2_precision', '3_precision', '4_precision', '5_precision'])

# %%
plot_list_of_columns_in_y_axis(df,
                               columns=['0_recall', '1_recall', '2_recall', '3_recall', '4_recall', '5_recall'],
                               plot_title='Recall')

# %%
df.plot(y=['accuracy'])
# Out:
# <Axes: >

# %%
plot_list_of_columns_in_y_axis(df,
                               columns=['0_f1-score', '1_f1-score', '2_f1-score', '3_f1-score', '4_f1-score', '5_f1-score'],
                               plot_title='f1-score')

# %%
df['accuracy'][6:].mean()
# Out:
# 0.8188512518409425
