# %%
import pandas as pd

df = pd.read_csv('data.csv')
df
# Out:
#     Unnamed: 0  model_layer  0_precision  0_recall  0_f1-score  0_support  \
# 0            0          0.0     0.911227  0.719588    0.804147      485.0
# 1            1          1.0     0.881612  0.721649    0.793651      485.0
# 2            2          2.0     0.864532  0.723711    0.787879      485.0
# 3            3          3.0     0.847458  0.721649    0.779510      485.0
# 4            4          4.0     0.831707  0.703093    0.762011      485.0
# 5            5          5.0     0.800493  0.670103    0.729517      485.0
# 6            6          6.0     0.766169  0.635052    0.694476      485.0
# 7            7          7.0     0.791878  0.643299    0.709898      485.0
# 8            8          8.0     0.783375  0.641237    0.705215      485.0
# 9            9          9.0     0.788945  0.647423    0.711212      485.0
# 10          10         10.0     0.753027  0.641237    0.692650      485.0
# 11          11         11.0     0.737864  0.626804    0.677815      485.0
# 12          12         12.0     0.801008  0.655670    0.721088      485.0
#
#     1_precision  1_recall  1_f1-score  1_support  ...  5_support  accuracy  \
# 0      0.519101  0.785714    0.625169      294.0  ...      427.0  0.735438
# 1      0.502146  0.795918    0.615789      294.0  ...      427.0  0.731881
# 2      0.506438  0.802721    0.621053      294.0  ...      427.0  0.731436
# 3      0.491954  0.727891    0.587106      294.0  ...      427.0  0.716318
# 4      0.471739  0.738095    0.575597      294.0  ...      427.0  0.696754
# 5      0.454352  0.727891    0.559477      294.0  ...      427.0  0.675411
# 6      0.443983  0.727891    0.551546      294.0  ...      427.0  0.652735
# 7      0.429719  0.727891    0.540404      294.0  ...      427.0  0.649622
# 8      0.416499  0.704082    0.523388      294.0  ...      427.0  0.638506
# 9      0.408284  0.704082    0.516854      294.0  ...      427.0  0.627835
# 10     0.390291  0.683673    0.496910      294.0  ...      427.0  0.614051
# 11     0.375486  0.656463    0.477723      294.0  ...      427.0  0.594931
# 12     0.437768  0.693878    0.536842      294.0  ...      427.0  0.648288
#
#     macro avg_precision  macro avg_recall  macro avg_f1-score  \
# 0              0.743959          0.738202            0.732242
# 1              0.741393          0.734359            0.729095
# 2              0.739807          0.733616            0.728394
# 3              0.720957          0.715463            0.712086
# 4              0.705889          0.697873            0.693922
# 5              0.688542          0.677852            0.673589
# 6              0.670221          0.656735            0.652134
# 7              0.667214          0.652854            0.648586
# 8              0.656899          0.641027            0.637633
# 9              0.645515          0.629593            0.626007
# 10             0.634601          0.614959            0.612626
# 11             0.615766          0.595714            0.593570
# 12             0.661028          0.650998            0.646192
#
#     macro avg_support  weighted avg_precision  weighted avg_recall  \
# 0              2249.0                0.767043             0.735438
# 1              2249.0                0.762836             0.731881
# 2              2249.0                0.759871             0.731436
# 3              2249.0                0.741147             0.716318
# 4              2249.0                0.726134             0.696754
# 5              2249.0                0.709555             0.675411
# 6              2249.0                0.690764             0.652735
# 7              2249.0                0.689118             0.649622
# 8              2249.0                0.678744             0.638506
# 9              2249.0                0.668307             0.627835
# 10             2249.0                0.657237             0.614051
# 11             2249.0                0.638226             0.594931
# 12             2249.0                0.682561             0.648288
#
#     weighted avg_f1-score  weighted avg_support
# 0                0.742732                2249.0
# 1                0.739233                2249.0
# 2                0.738053                2249.0
# 3                0.723074                2249.0
# 4                0.704117                2249.0
# 5                0.683506                2249.0
# 6                0.661074                2249.0
# 7                0.658690                2249.0
# 8                0.648060                2249.0
# 9                0.637249                2249.0
# 10               0.624276                2249.0
# 11               0.605041                2249.0
# 12               0.656051                2249.0
#
# [13 rows x 35 columns]

# %%
from matplotlib import pyplot as plt

def plot_each_column_in_same_plot(df):
    # plot each column in same plot
    df.plot()
    plt.show()

# %%
def plot_list_of_columns_in_y_axis(df, columns, plot_title='Precision'):
    # plot each column in same plot

    df.plot(y=columns)
    plt.title(plot_title)
    plt.legend(['Acc', 'Dat', 'Gen', 'Loc', 'Ins', 'Nom'], loc='lower right')
    plt.show()

# %%
plot_list_of_columns_in_y_axis(df,
                               columns=['0_precision', '1_precision', '2_precision', '3_precision', '4_precision', '5_precision'])

# %%
plot_list_of_columns_in_y_axis(df,
                               columns=['0_recall', '1_recall', '2_recall', '3_recall', '4_recall', '5_recall'],
                               plot_title='Recall')

# %%
df['accuracy'][6:].mean()
# Out:
# 0.6322810137839039
