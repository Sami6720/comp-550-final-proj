# %%
import pandas as pd

df = pd.read_csv('data.csv')
df
# Out:
#     Unnamed: 0  model_layer  0_precision  0_recall  0_f1-score  0_support  \
# 0            0          0.0     0.516129  0.095238    0.160804      168.0
# 1            1          1.0     0.396450  0.398810    0.397626      168.0
# 2            2          2.0     0.314103  0.583333    0.408333      168.0
# 3            3          3.0     0.218807  0.720238    0.335645      168.0
# 4            4          4.0     0.777778  0.041667    0.079096      168.0
# 5            5          5.0     0.391586  0.720238    0.507338      168.0
# 6            6          6.0     0.216216  0.761905    0.336842      168.0
# 7            7          7.0     0.353712  0.482143    0.408060      168.0
# 8            8          8.0     0.272464  0.559524    0.366472      168.0
# 9            9          9.0     0.234043  0.851190    0.367137      168.0
# 10          10         10.0     0.464968  0.434524    0.449231      168.0
# 11          11         11.0     0.459259  0.738095    0.566210      168.0
# 12          12         12.0     0.000000  0.000000    0.000000      168.0
#
#     1_precision  1_recall  1_f1-score  1_support  ...  5_support  accuracy  \
# 0      0.090667  0.472222    0.152125       72.0  ...      349.0  0.375258
# 1      0.110312  0.638889    0.188139       72.0  ...      349.0  0.428866
# 2      0.099366  0.652778    0.172477       72.0  ...      349.0  0.282474
# 3      0.341935  0.736111    0.466960       72.0  ...      349.0  0.457045
# 4      0.619048  0.180556    0.279570       72.0  ...      349.0  0.476289
# 5      0.736842  0.194444    0.307692       72.0  ...      349.0  0.549141
# 6      0.328767  0.333333    0.331034       72.0  ...      349.0  0.193127
# 7      0.228448  0.736111    0.348684       72.0  ...      349.0  0.502405
# 8      0.500000  0.013889    0.027027       72.0  ...      349.0  0.427491
# 9      0.190476  0.333333    0.242424       72.0  ...      349.0  0.432302
# 10     0.947368  0.250000    0.395604       72.0  ...      349.0  0.457045
# 11     0.000000  0.000000    0.000000       72.0  ...      349.0  0.653608
# 12     0.223938  0.805556    0.350453       72.0  ...      349.0  0.536082
#
#     macro avg_precision  macro avg_recall  macro avg_f1-score  \
# 0              0.374347          0.357975            0.302464
# 1              0.370351          0.433206            0.351862
# 2              0.410887          0.472863            0.317652
# 3              0.398299          0.470195            0.389861
# 4              0.567255          0.453304            0.393465
# 5              0.548504          0.527970            0.478931
# 6              0.301239          0.372207            0.185942
# 7              0.512211          0.464748            0.402318
# 8              0.445426          0.390314            0.338254
# 9              0.480962          0.440846            0.354273
# 10             0.556494          0.528659            0.464762
# 11             0.575768          0.464246            0.477068
# 12             0.386356          0.410725            0.321742
#
#     macro avg_support  weighted avg_precision  weighted avg_recall  \
# 0              1455.0                0.549935             0.375258
# 1              1455.0                0.579721             0.428866
# 2              1455.0                0.612086             0.282474
# 3              1455.0                0.555105             0.457045
# 4              1455.0                0.635161             0.476289
# 5              1455.0                0.596676             0.549141
# 6              1455.0                0.299599             0.193127
# 7              1455.0                0.579018             0.502405
# 8              1455.0                0.548956             0.427491
# 9              1455.0                0.611645             0.432302
# 10             1455.0                0.574128             0.457045
# 11             1455.0                0.642979             0.653608
# 12             1455.0                0.489381             0.536082
#
#     weighted avg_f1-score  weighted avg_support
# 0                0.400404                1455.0
# 1                0.454750                1455.0
# 2                0.228141                1455.0
# 3                0.465916                1455.0
# 4                0.474720                1455.0
# 5                0.542048                1455.0
# 6                0.093119                1455.0
# 7                0.497934                1455.0
# 8                0.407493                1455.0
# 9                0.432093                1455.0
# 10               0.462891                1455.0
# 11               0.625671                1455.0
# 12               0.430931                1455.0
#
# [13 rows x 35 columns]

# %%
from matplotlib import pyplot as plt

def plot_each_column_in_same_plot(df):
    # plot each column in same plot
    df.plot()
    plt.show()

# %%
def plot_list_of_columns_in_y_axis(df, columns, plot_title='Precision'):
    # plot each column in same plot

    df.plot(y=columns)
    plt.title(plot_title)
    plt.legend(['Acc', 'Dat', 'Gen', 'Loc', 'Ins', 'Nom'], loc='lower right')
    plt.show()

# %%
df.plot(y=['accuracy'])
# Out:
# <Axes: >

# %%
df['accuracy'][10:].mean()
# Out:
# 0.5489117983963344
