# %%
import pandas as pd

df = pd.read_csv('data.csv')
df
# Out:
#     Unnamed: 0  model_layer  0_precision  0_recall  0_f1-score  0_support  \
# 0            0          0.0     0.400000  0.559524    0.466501      168.0
# 1            1          1.0     0.520737  0.672619    0.587013      168.0
# 2            2          2.0     0.521327  0.654762    0.580475      168.0
# 3            3          3.0     0.533040  0.720238    0.612658      168.0
# 4            4          4.0     0.545455  0.714286    0.618557      168.0
# 5            5          5.0     0.641711  0.714286    0.676056      168.0
# 6            6          6.0     0.661616  0.779762    0.715847      168.0
# 7            7          7.0     0.656250  0.750000    0.700000      168.0
# 8            8          8.0     0.737430  0.785714    0.760807      168.0
# 9            9          9.0     0.727273  0.761905    0.744186      168.0
# 10          10         10.0     0.673575  0.773810    0.720222      168.0
# 11          11         11.0     0.675676  0.744048    0.708215      168.0
# 12          12         12.0     0.613065  0.726190    0.664850      168.0
#
#     1_precision  1_recall  1_f1-score  1_support  ...  5_support  accuracy  \
# 0      0.345324  0.666667    0.454976       72.0  ...      349.0  0.544330
# 1      0.368000  0.638889    0.467005       72.0  ...      349.0  0.625430
# 2      0.464646  0.638889    0.538012       72.0  ...      349.0  0.659107
# 3      0.551020  0.750000    0.635294       72.0  ...      349.0  0.709278
# 4      0.569892  0.736111    0.642424       72.0  ...      349.0  0.715464
# 5      0.568627  0.805556    0.666667       72.0  ...      349.0  0.749141
# 6      0.714286  0.833333    0.769231       72.0  ...      349.0  0.793127
# 7      0.698925  0.902778    0.787879       72.0  ...      349.0  0.797251
# 8      0.695652  0.888889    0.780488       72.0  ...      349.0  0.810997
# 9      0.656250  0.875000    0.750000       72.0  ...      349.0  0.806186
# 10     0.719101  0.888889    0.795031       72.0  ...      349.0  0.796564
# 11     0.715909  0.875000    0.787500       72.0  ...      349.0  0.801375
# 12     0.673913  0.861111    0.756098       72.0  ...      349.0  0.764948
#
#     macro avg_precision  macro avg_recall  macro avg_f1-score  \
# 0              0.475630          0.582429            0.506205
# 1              0.543203          0.651342            0.576624
# 2              0.581923          0.681886            0.616590
# 3              0.635882          0.736139            0.673419
# 4              0.644964          0.742771            0.682113
# 5              0.683668          0.770444            0.719095
# 6              0.733594          0.811087            0.765966
# 7              0.739036          0.825500            0.775452
# 8              0.753993          0.833994            0.787856
# 9              0.746484          0.829342            0.781093
# 10             0.748684          0.833519            0.784755
# 11             0.760033          0.836821            0.793472
# 12             0.727760          0.802960            0.759968
#
#     macro avg_support  weighted avg_precision  weighted avg_recall  \
# 0              1455.0                0.603731             0.544330
# 1              1455.0                0.681128             0.625430
# 2              1455.0                0.696013             0.659107
# 3              1455.0                0.739796             0.709278
# 4              1455.0                0.743447             0.715464
# 5              1455.0                0.765101             0.749141
# 6              1455.0                0.805672             0.793127
# 7              1455.0                0.809725             0.797251
# 8              1455.0                0.821496             0.810997
# 9              1455.0                0.818339             0.806186
# 10             1455.0                0.807942             0.796564
# 11             1455.0                0.811964             0.801375
# 12             1455.0                0.780072             0.764948
#
#     weighted avg_f1-score  weighted avg_support
# 0                0.556491                1455.0
# 1                0.637883                1455.0
# 2                0.667496                1455.0
# 3                0.715858                1455.0
# 4                0.721330                1455.0
# 5                0.752581                1455.0
# 6                0.795824                1455.0
# 7                0.799672                1455.0
# 8                0.813153                1455.0
# 9                0.808755                1455.0
# 10               0.798533                1455.0
# 11               0.803281                1455.0
# 12               0.767867                1455.0
#
# [13 rows x 35 columns]

# %%
from matplotlib import pyplot as plt

def plot_each_column_in_same_plot(df):
    # plot each column in same plot
    df.plot()
    plt.show()

# %%
def plot_list_of_columns_in_y_axis(df, columns, plot_title='Precision'):
    # plot each column in same plot

    df.plot(y=columns)
    plt.title(plot_title)
    plt.legend(['Acc', 'Dat', 'Gen', 'Loc', 'Ins', 'Nom'], loc='lower right')
    plt.show()

# %%
plot_list_of_columns_in_y_axis(df,
                               columns=['0_precision', '1_precision', '2_precision', '3_precision', '4_precision', '5_precision'])

# %%
plot_list_of_columns_in_y_axis(df,
                               columns=['0_recall', '1_recall', '2_recall', '3_recall', '4_recall', '5_recall'],
                               plot_title='Recall')

# %%
df.plot(y=['accuracy'])
# Out:
# <Axes: >

# %%
plot_list_of_columns_in_y_axis(df,
                               columns=['0_f1-score', '1_f1-score', '2_f1-score', '3_f1-score', '4_f1-score', '5_f1-score'],
                               plot_title='f1-score')

# %%
df['accuracy'][6:].mean()
# Out:
# 0.7957781050564555
